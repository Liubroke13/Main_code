# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines

# %%
a_0 = 1
a_1 = [1/2 , np.sqrt(3)/2]
a_2 = [-1/2, np.sqrt(3)/2]
Nx = 3
Ny = 3

# %%
# betalpha = np.array([[0, 0], [np.pi, 0], [np.pi/2, 0], [np.pi/2, np.pi]])
Q_c=1
fig, ax = plt.subplots(figsize=(3, 3), constrained_layout=False, dpi=300)


#plot X atom in real space
x=[]
y=[]
for j in range(Ny):
    for i in range(Nx):
        x+=[a_0*(0+i*a_1[0]+j*a_2[0])]
        y+=[a_0*(1/np.sqrt(3)+i*a_1[1]+j*a_2[1])]
print(x, y)
ax.plot(x, y, linewidth=0, marker='.', color='y')

#plot M atom in real space
x=[]
y=[]
for j in range(Ny):
    for i in range(Nx):
        x+=[a_0*(0+i*a_1[0]+j*a_2[0])]
        y+=[a_0*(2/np.sqrt(3)+i*a_1[1]+j*a_2[1])]
print(x, y)
ax.plot(x, y, linewidth=0, marker='o', color='purple')

#plot cell in real space
lines = [
    ([0, a_1[0]], [0, a_1[1]]),
    ([0, a_2[0]], [0, a_2[1]])
]
for lx, ly in lines:
    ax.plot(lx, ly, color='gray', linewidth=0.5, zorder=0)


ax.set_xlim(min(x)-2, max(x)+2)
ax.set_ylim(min(y)-2, max(y)+2)
# ax.set_xticks([])
# ax.set_yticks([])
# fig.subplots_adjust(left=0.075, bottom=0.1, right=0.9, top=0.9, wspace=0, hspace=0.06 )
plt.tight_layout()
plt.show()
# Out:
# [0.0, 0.5, 1.0, -0.5, 0.0, 0.5, -1.0, -0.5, 0.0] [0.5773502691896258, 1.4433756729740645, 2.309401076758503, 1.4433756729740645, 2.309401076758503, 3.1754264805429413, 2.309401076758503, 3.1754264805429417, 4.04145188432738]
# [0.0, 0.5, 1.0, -0.5, 0.0, 0.5, -1.0, -0.5, 0.0] [1.1547005383792517, 2.0207259421636903, 2.886751345948129, 2.0207259421636903, 2.886751345948129, 3.7527767497325675, 2.886751345948129, 3.7527767497325675, 4.618802153517006]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
